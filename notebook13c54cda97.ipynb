# %%
# !pip install -q kagglehub

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
files = kagglehub.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_47/4001892458.py in <cell line: 0>()
# ----> 1 files = kagglehub.dataset_files("anshankul/ibm-amlsim-example-dataset")
#
# AttributeError: module 'kagglehub' has no attribute 'dataset_files'
